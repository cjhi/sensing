# %%
from binary_to_csv import binary_to_csv
import pandas as pd

binary_to_csv("flightData.TXT", "flightData.csv", 60, "<Lffffffffffifff")
data = pd.read_csv("flightData.csv")

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
for column in data.columns:
    plt.figure()
    plt.plot(data["Time since launch (ms)"], data[column])
    plt.title(column)

# %%
data[["Altitude (m)", "Kalman Altitude"]]
# Out:
#     Altitude (m)  Kalman Altitude
# 0       214.8750         214.8750
# 1       215.1250         215.1250
# 2       214.6875         214.6875
# 3       214.4375         214.4375
# 4       214.9375         214.9375
# ..           ...              ...
# 87      213.2500         213.2500
# 88      212.8750         212.8750
# 89      213.0625         213.0625
# 90      212.5625         212.5625
# 91      212.5000         212.5000
#
# [92 rows x 2 columns]
