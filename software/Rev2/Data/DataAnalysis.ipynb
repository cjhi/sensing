# %%
from binary_to_csv import binary_to_csv

binary_to_csv("4_15_22_test2.txt", "4_15_22_test2.csv", )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1836/232036466.py in <module>
#       1 from binary_to_csv import binary_to_csv
#       2
# ----> 3 binary_to_csv("4_15_22_test2.txt", "4_15_22_test2.csv")
#
# TypeError: binary_to_csv() missing 2 required positional arguments: 'num_bytes' and 'format'

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Flight_1.csv")
data = data.drop(data.index[-1])
plt.plot(data["Time since launch (ms)"], data["Altitude (m)"])
